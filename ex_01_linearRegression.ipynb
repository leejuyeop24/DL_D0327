# %% [markdown]
# [DL 구동 과정]

# %%
## 모듈 로딩
import torch						## 텐서 관련 모듈
import torch.nn as nn				## 인공신경망 관련 모듈
import torch.nn.functional as F		## 활성화, 손실 등 함수들 모듈
import torch.optim as optim

# %%
# 현재 실습하고 있는 파이썬 코드를 재실행해도
# 다음에도 같은 결과가 나오도록 랜덤 시드(random seed) 설정
torch.manual_seed(1)

# %%
# 데이터 준비 --------------------------------------------------
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
print(f'x_train : {x_train.shape}, {x_train.ndim} \n{x_train}')
print(f'y_train : {y_train.shape}, {y_train.ndim} \n{y_train}')
# Out:
# x_train : torch.Size([3, 1]), 2
# tensor([[1.],
#         [2.],
#         [3.]])
# y_train : torch.Size([3, 1]), 2
# tensor([[2.],
#         [4.],
#         [6.]])

# %%
# Model 초기화 -------------------------------------------------
# 가중치 W 0으로 초기화하고 학습 통해 값이 변경되는 변수 명시함
# requires_grad=True  <= 학습을 통해 계속 값이 변경되는 변수임 의미
# y= Wx+b = 0x + 0
# torch.zeros(텐서 원소 갯수)
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

print(f'W : {W}, b : {b}')
# Out:
# W : tensor([0.], requires_grad=True), b : tensor([0.], requires_grad=True)

# %%
# 경사하강법 => W,b 업데이트
# W,b 변수, 학습률지정
optimizer = optim.SGD([W, b], lr=0.01)

# %%
# 학습 --------------------------------------------------------
nb_epochs = 1999 # 원하는만큼 경사 하강법을 반복

for epoch in range(nb_epochs + 1):

    # H(x) 계산 = XW+b => 예측값
    hypothesis = x_train * W + b

    # cost 계산 = (예측값 - 정답)
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    optimizer.zero_grad()      # gradient를 0으로 초기화
    cost.backward()            # 비용 함수를 미분하여 gradient 계산
    print('수식을 w로 미분한 값 : {}'.format(W.grad))

    optimizer.step()           # W, b 업데이트
    print(f'업데이트 된 W : {W.grad}, b : {b.grad}')


    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print(f'Epoch {epoch:4d}/{nb_epochs} W: { W.item():.3f}, b: {b.item():.3f} Cost: {cost.item():.6f}')
# Out:
# 수식을 w로 미분한 값 : tensor([-0.0111])
# 업데이트 된 W : tensor([-0.0111]), b : tensor([0.0253])
# Epoch    0/1999 W: 1.954, b: 0.105 Cost: 0.001595
# 수식을 w로 미분한 값 : tensor([-0.0111])
# 업데이트 된 W : tensor([-0.0111]), b : tensor([0.0253])
# 수식을 w로 미분한 값 : tensor([-0.0111])
# 업데이트 된 W : tensor([-0.0111]), b : tensor([0.0252])
# 수식을 w로 미분한 값 : tensor([-0.0111])
# 업데이트 된 W : tensor([-0.0111]), b : tensor([0.0252])
# 수식을 w로 미분한 값 : tensor([-0.0110])
# 업데이트 된 W : tensor([-0.0110]), b : tensor([0.0251])
# 수식을 w로 미분한 값 : tensor([-0.0110])
# 업데이트 된 W : tensor([-0.0110]), b : tensor([0.0250])
# 수식을 w로 미분한 값 : tensor([-0.0110])
# 업데이트 된 W : tensor([-0.0110]), b : tensor([0.0250])
# 수식을 w로 미분한 값 : tensor([-0.0110])
# 업데이트 된 W : tensor([-0.0110]), b : tensor([0.0249])
# 수식을 w로 미분한 값 : tensor([-0.0109])
# 업데이트 된 W : tensor([-0.0109]), b : tensor([0.0249])
# 수식을 w로 미분한 값 : tensor([-0.0109])
# 업데이트 된 W : tensor([-0.0109]), b : tensor([0.0248])
# 수식을 w로 미분한 값 : tensor([-0.0109])
# 업데이트 된 W : tensor([-0.0109]), b : tensor([0.0247])
# 수식을 w로 미분한 값 : tensor([-0.0109])
# 업데이트 된 W : tensor([-0.0109]), b : tensor([0.0247])
# 수식을 w로 미분한 값 : tensor([-0.0108])
# 업데이트 된 W : tensor([-0.0108]), b : tensor([0.0246])
# 수식을 w로 미분한 값 : tensor([-0.0108])
# 업데이트 된 W : tensor([-0.0108]), b : tensor([0.0246])
# 수식을 w로 미분한 값 : tensor([-0.0108])
# 업데이트 된 W : tensor([-0.0108]), b : tensor([0.0245])
# 수식을 w로 미분한 값 : tensor([-0.0108])
# 업데이트 된 W : tensor([-0.0108]), b : tensor([0.0244])
# 수식을 w로 미분한 값 : tensor([-0.0107])
# 업데이트 된 W : tensor([-0.0107]), b : tensor([0.0244])
# 수식을 w로 미분한 값 : tensor([-0.0107])
# 업데이트 된 W : tensor([-0.0107]), b : tensor([0.0243])
# 수식을 w로 미분한 값 : tensor([-0.0107])
# 업데이트 된 W : tensor([-0.0107]), b : tensor([0.0243])
# 수식을 w로 미분한 값 : tensor([-0.0107])
# 업데이트 된 W : tensor([-0.0107]), b : tensor([0.0242])
# 수식을 w로 미분한 값 : tensor([-0.0106])
# 업데이트 된 W : tensor([-0.0106]), b : tensor([0.0242])
# 수식을 w로 미분한 값 : tensor([-0.0106])
# 업데이트 된 W : tensor([-0.0106]), b : tensor([0.0241])
# 수식을 w로 미분한 값 : tensor([-0.0106])
# 업데이트 된 W : tensor([-0.0106]), b : tensor([0.0240])
# 수식을 w로 미분한 값 : tensor([-0.0105])
# 업데이트 된 W : tensor([-0.0105]), b : tensor([0.0240])
# 수식을 w로 미분한 값 : tensor([-0.0105])
# 업데이트 된 W : tensor([-0.0105]), b : tensor([0.0239])
# 수식을 w로 미분한 값 : tensor([-0.0105])
# 업데이트 된 W : tensor([-0.0105]), b : tensor([0.0239])
# 수식을 w로 미분한 값 : tensor([-0.0105])
# 업데이트 된 W : tensor([-0.0105]), b : tensor([0.0238])
# 수식을 w로 미분한 값 : tensor([-0.0104])
# 업데이트 된 W : tensor([-0.0104]), b : tensor([0.0238])
# 수식을 w로 미분한 값 : tensor([-0.0104])
# 업데이트 된 W : tensor([-0.0104]), b : tensor([0.0237])
# 수식을 w로 미분한 값 : tensor([-0.0104])
# 업데이트 된 W : tensor([-0.0104]), b : tensor([0.0236])
# 수식을 w로 미분한 값 : tensor([-0.0104])
# 업데이트 된 W : tensor([-0.0104]), b : tensor([0.0236])
# 수식을 w로 미분한 값 : tensor([-0.0103])
# 업데이트 된 W : tensor([-0.0103]), b : tensor([0.0235])
# 수식을 w로 미분한 값 : tensor([-0.0103])
# 업데이트 된 W : tensor([-0.0103]), b : tensor([0.0235])
# 수식을 w로 미분한 값 : tensor([-0.0103])
# 업데이트 된 W : tensor([-0.0103]), b : tensor([0.0234])
# 수식을 w로 미분한 값 : tensor([-0.0103])
# 업데이트 된 W : tensor([-0.0103]), b : tensor([0.0234])
# 수식을 w로 미분한 값 : tensor([-0.0102])
# 업데이트 된 W : tensor([-0.0102]), b : tensor([0.0233])
# 수식을 w로 미분한 값 : tensor([-0.0102])
# 업데이트 된 W : tensor([-0.0102]), b : tensor([0.0232])
# 수식을 w로 미분한 값 : tensor([-0.0102])
# 업데이트 된 W : tensor([-0.0102]), b : tensor([0.0232])
# 수식을 w로 미분한 값 : tensor([-0.0102])
# 업데이트 된 W : tensor([-0.0102]), b : tensor([0.0231])
# 수식을 w로 미분한 값 : tensor([-0.0101])
# 업데이트 된 W : tensor([-0.0101]), b : tensor([0.0231])
# 수식을 w로 미분한 값 : tensor([-0.0101])
# 업데이트 된 W : tensor([-0.0101]), b : tensor([0.0230])
# 수식을 w로 미분한 값 : tensor([-0.0101])
# 업데이트 된 W : tensor([-0.0101]), b : tensor([0.0230])
# 수식을 w로 미분한 값 : tensor([-0.0101])
# 업데이트 된 W : tensor([-0.0101]), b : tensor([0.0229])
# 수식을 w로 미분한 값 : tensor([-0.0101])
# 업데이트 된 W : tensor([-0.0101]), b : tensor([0.0229])
# 수식을 w로 미분한 값 : tensor([-0.0100])
# 업데이트 된 W : tensor([-0.0100]), b : tensor([0.0228])
# 수식을 w로 미분한 값 : tensor([-0.0100])
# 업데이트 된 W : tensor([-0.0100]), b : tensor([0.0227])
# 수식을 w로 미분한 값 : tensor([-0.0100])
# 업데이트 된 W : tensor([-0.0100]), b : tensor([0.0227])
# 수식을 w로 미분한 값 : tensor([-0.0100])
# 업데이트 된 W : tensor([-0.0100]), b : tensor([0.0226])
# 수식을 w로 미분한 값 : tensor([-0.0099])
# 업데이트 된 W : tensor([-0.0099]), b : tensor([0.0226])
# 수식을 w로 미분한 값 : tensor([-0.0099])
# 업데이트 된 W : tensor([-0.0099]), b : tensor([0.0225])
# 수식을 w로 미분한 값 : tensor([-0.0099])
# 업데이트 된 W : tensor([-0.0099]), b : tensor([0.0225])
# 수식을 w로 미분한 값 : tensor([-0.0099])
# 업데이트 된 W : tensor([-0.0099]), b : tensor([0.0224])
# 수식을 w로 미분한 값 : tensor([-0.0098])
# 업데이트 된 W : tensor([-0.0098]), b : tensor([0.0224])
# 수식을 w로 미분한 값 : tensor([-0.0098])
# 업데이트 된 W : tensor([-0.0098]), b : tensor([0.0223])
# 수식을 w로 미분한 값 : tensor([-0.0098])
# 업데이트 된 W : tensor([-0.0098]), b : tensor([0.0223])
# 수식을 w로 미분한 값 : tensor([-0.0098])
# 업데이트 된 W : tensor([-0.0098]), b : tensor([0.0222])
# 수식을 w로 미분한 값 : tensor([-0.0097])
# 업데이트 된 W : tensor([-0.0097]), b : tensor([0.0221])
# 수식을 w로 미분한 값 : tensor([-0.0097])
# 업데이트 된 W : tensor([-0.0097]), b : tensor([0.0221])
# 수식을 w로 미분한 값 : tensor([-0.0097])
# 업데이트 된 W : tensor([-0.0097]), b : tensor([0.0220])
# 수식을 w로 미분한 값 : tensor([-0.0097])
# 업데이트 된 W : tensor([-0.0097]), b : tensor([0.0220])
# 수식을 w로 미분한 값 : tensor([-0.0097])
# 업데이트 된 W : tensor([-0.0097]), b : tensor([0.0219])
# 수식을 w로 미분한 값 : tensor([-0.0096])
# 업데이트 된 W : tensor([-0.0096]), b : tensor([0.0219])
# 수식을 w로 미분한 값 : tensor([-0.0096])
# 업데이트 된 W : tensor([-0.0096]), b : tensor([0.0218])
# 수식을 w로 미분한 값 : tensor([-0.0096])
# 업데이트 된 W : tensor([-0.0096]), b : tensor([0.0218])
# 수식을 w로 미분한 값 : tensor([-0.0096])
# 업데이트 된 W : tensor([-0.0096]), b : tensor([0.0217])
# 수식을 w로 미분한 값 : tensor([-0.0095])
# 업데이트 된 W : tensor([-0.0095]), b : tensor([0.0217])
# 수식을 w로 미분한 값 : tensor([-0.0095])
# 업데이트 된 W : tensor([-0.0095]), b : tensor([0.0216])
# 수식을 w로 미분한 값 : tensor([-0.0095])
# 업데이트 된 W : tensor([-0.0095]), b : tensor([0.0216])
# 수식을 w로 미분한 값 : tensor([-0.0095])
# 업데이트 된 W : tensor([-0.0095]), b : tensor([0.0215])
# 수식을 w로 미분한 값 : tensor([-0.0094])
# 업데이트 된 W : tensor([-0.0094]), b : tensor([0.0215])
# 수식을 w로 미분한 값 : tensor([-0.0094])
# 업데이트 된 W : tensor([-0.0094]), b : tensor([0.0214])
# 수식을 w로 미분한 값 : tensor([-0.0094])
# 업데이트 된 W : tensor([-0.0094]), b : tensor([0.0214])
# 수식을 w로 미분한 값 : tensor([-0.0094])
# 업데이트 된 W : tensor([-0.0094]), b : tensor([0.0213])
# 수식을 w로 미분한 값 : tensor([-0.0094])
# 업데이트 된 W : tensor([-0.0094]), b : tensor([0.0213])
# 수식을 w로 미분한 값 : tensor([-0.0093])
# 업데이트 된 W : tensor([-0.0093]), b : tensor([0.0212])
# 수식을 w로 미분한 값 : tensor([-0.0093])
# 업데이트 된 W : tensor([-0.0093]), b : tensor([0.0212])
# 수식을 w로 미분한 값 : tensor([-0.0093])
# 업데이트 된 W : tensor([-0.0093]), b : tensor([0.0211])
# 수식을 w로 미분한 값 : tensor([-0.0093])
# 업데이트 된 W : tensor([-0.0093]), b : tensor([0.0211])
# 수식을 w로 미분한 값 : tensor([-0.0092])
# 업데이트 된 W : tensor([-0.0092]), b : tensor([0.0210])
# 수식을 w로 미분한 값 : tensor([-0.0092])
# 업데이트 된 W : tensor([-0.0092]), b : tensor([0.0210])
# 수식을 w로 미분한 값 : tensor([-0.0092])
# 업데이트 된 W : tensor([-0.0092]), b : tensor([0.0209])
# 수식을 w로 미분한 값 : tensor([-0.0092])
# 업데이트 된 W : tensor([-0.0092]), b : tensor([0.0209])
# 수식을 w로 미분한 값 : tensor([-0.0092])
# 업데이트 된 W : tensor([-0.0092]), b : tensor([0.0208])
# 수식을 w로 미분한 값 : tensor([-0.0091])
# 업데이트 된 W : tensor([-0.0091]), b : tensor([0.0208])
# 수식을 w로 미분한 값 : tensor([-0.0091])
# 업데이트 된 W : tensor([-0.0091]), b : tensor([0.0207])
# 수식을 w로 미분한 값 : tensor([-0.0091])
# 업데이트 된 W : tensor([-0.0091]), b : tensor([0.0207])
# 수식을 w로 미분한 값 : tensor([-0.0091])
# 업데이트 된 W : tensor([-0.0091]), b : tensor([0.0206])
# 수식을 w로 미분한 값 : tensor([-0.0090])
# 업데이트 된 W : tensor([-0.0090]), b : tensor([0.0206])
# 수식을 w로 미분한 값 : tensor([-0.0090])
# 업데이트 된 W : tensor([-0.0090]), b : tensor([0.0205])
# 수식을 w로 미분한 값 : tensor([-0.0090])
# 업데이트 된 W : tensor([-0.0090]), b : tensor([0.0205])
# 수식을 w로 미분한 값 : tensor([-0.0090])
# 업데이트 된 W : tensor([-0.0090]), b : tensor([0.0204])
# 수식을 w로 미분한 값 : tensor([-0.0090])
# 업데이트 된 W : tensor([-0.0090]), b : tensor([0.0204])
# 수식을 w로 미분한 값 : tensor([-0.0089])
# 업데이트 된 W : tensor([-0.0089]), b : tensor([0.0203])
# 수식을 w로 미분한 값 : tensor([-0.0089])
# 업데이트 된 W : tensor([-0.0089]), b : tensor([0.0203])
# 수식을 w로 미분한 값 : tensor([-0.0089])
# 업데이트 된 W : tensor([-0.0089]), b : tensor([0.0202])
# 수식을 w로 미분한 값 : tensor([-0.0089])
# 업데이트 된 W : tensor([-0.0089]), b : tensor([0.0202])
# 수식을 w로 미분한 값 : tensor([-0.0088])
# 업데이트 된 W : tensor([-0.0088]), b : tensor([0.0201])
# 수식을 w로 미분한 값 : tensor([-0.0088])
# 업데이트 된 W : tensor([-0.0088]), b : tensor([0.0201])
# 수식을 w로 미분한 값 : tensor([-0.0088])
# 업데이트 된 W : tensor([-0.0088]), b : tensor([0.0200])
# 수식을 w로 미분한 값 : tensor([-0.0088])
# 업데이트 된 W : tensor([-0.0088]), b : tensor([0.0200])
# 수식을 w로 미분한 값 : tensor([-0.0088])
# 업데이트 된 W : tensor([-0.0088]), b : tensor([0.0199])
# Epoch  100/1999 W: 1.964, b: 0.083 Cost: 0.000985
# 수식을 w로 미분한 값 : tensor([-0.0087])
# 업데이트 된 W : tensor([-0.0087]), b : tensor([0.0199])
# 수식을 w로 미분한 값 : tensor([-0.0087])
# 업데이트 된 W : tensor([-0.0087]), b : tensor([0.0198])
# 수식을 w로 미분한 값 : tensor([-0.0087])
# 업데이트 된 W : tensor([-0.0087]), b : tensor([0.0198])
# 수식을 w로 미분한 값 : tensor([-0.0087])
# 업데이트 된 W : tensor([-0.0087]), b : tensor([0.0197])
# 수식을 w로 미분한 값 : tensor([-0.0087])
# 업데이트 된 W : tensor([-0.0087]), b : tensor([0.0197])
# 수식을 w로 미분한 값 : tensor([-0.0086])
# 업데이트 된 W : tensor([-0.0086]), b : tensor([0.0196])
# 수식을 w로 미분한 값 : tensor([-0.0086])
# 업데이트 된 W : tensor([-0.0086]), b : tensor([0.0196])
# 수식을 w로 미분한 값 : tensor([-0.0086])
# 업데이트 된 W : tensor([-0.0086]), b : tensor([0.0195])
# 수식을 w로 미분한 값 : tensor([-0.0086])
# 업데이트 된 W : tensor([-0.0086]), b : tensor([0.0195])
# 수식을 w로 미분한 값 : tensor([-0.0086])
# 업데이트 된 W : tensor([-0.0086]), b : tensor([0.0194])
# 수식을 w로 미분한 값 : tensor([-0.0085])
# 업데이트 된 W : tensor([-0.0085]), b : tensor([0.0194])
# 수식을 w로 미분한 값 : tensor([-0.0085])
# 업데이트 된 W : tensor([-0.0085]), b : tensor([0.0194])
# 수식을 w로 미분한 값 : tensor([-0.0085])
# 업데이트 된 W : tensor([-0.0085]), b : tensor([0.0193])
# 수식을 w로 미분한 값 : tensor([-0.0085])
# 업데이트 된 W : tensor([-0.0085]), b : tensor([0.0193])
# 수식을 w로 미분한 값 : tensor([-0.0085])
# 업데이트 된 W : tensor([-0.0085]), b : tensor([0.0192])
# 수식을 w로 미분한 값 : tensor([-0.0084])
# 업데이트 된 W : tensor([-0.0084]), b : tensor([0.0192])
# 수식을 w로 미분한 값 : tensor([-0.0084])
# 업데이트 된 W : tensor([-0.0084]), b : tensor([0.0191])
# 수식을 w로 미분한 값 : tensor([-0.0084])
# 업데이트 된 W : tensor([-0.0084]), b : tensor([0.0191])
# 수식을 w로 미분한 값 : tensor([-0.0084])
# 업데이트 된 W : tensor([-0.0084]), b : tensor([0.0190])
# 수식을 w로 미분한 값 : tensor([-0.0084])
# 업데이트 된 W : tensor([-0.0084]), b : tensor([0.0190])
# 수식을 w로 미분한 값 : tensor([-0.0083])
# 업데이트 된 W : tensor([-0.0083]), b : tensor([0.0189])
# 수식을 w로 미분한 값 : tensor([-0.0083])
# 업데이트 된 W : tensor([-0.0083]), b : tensor([0.0189])
# 수식을 w로 미분한 값 : tensor([-0.0083])
# 업데이트 된 W : tensor([-0.0083]), b : tensor([0.0189])
# 수식을 w로 미분한 값 : tensor([-0.0083])
# 업데이트 된 W : tensor([-0.0083]), b : tensor([0.0188])
# 수식을 w로 미분한 값 : tensor([-0.0083])
# 업데이트 된 W : tensor([-0.0083]), b : tensor([0.0188])
# 수식을 w로 미분한 값 : tensor([-0.0082])
# 업데이트 된 W : tensor([-0.0082]), b : tensor([0.0187])
# 수식을 w로 미분한 값 : tensor([-0.0082])
# 업데이트 된 W : tensor([-0.0082]), b : tensor([0.0187])
# 수식을 w로 미분한 값 : tensor([-0.0082])
# 업데이트 된 W : tensor([-0.0082]), b : tensor([0.0186])
# 수식을 w로 미분한 값 : tensor([-0.0082])
# 업데이트 된 W : tensor([-0.0082]), b : tensor([0.0186])
# 수식을 w로 미분한 값 : tensor([-0.0082])
# 업데이트 된 W : tensor([-0.0082]), b : tensor([0.0185])
# 수식을 w로 미분한 값 : tensor([-0.0081])
# 업데이트 된 W : tensor([-0.0081]), b : tensor([0.0185])
# 수식을 w로 미분한 값 : tensor([-0.0081])
# 업데이트 된 W : tensor([-0.0081]), b : tensor([0.0184])
# 수식을 w로 미분한 값 : tensor([-0.0081])
# 업데이트 된 W : tensor([-0.0081]), b : tensor([0.0184])
# 수식을 w로 미분한 값 : tensor([-0.0081])
# 업데이트 된 W : tensor([-0.0081]), b : tensor([0.0184])
# 수식을 w로 미분한 값 : tensor([-0.0081])
# 업데이트 된 W : tensor([-0.0081]), b : tensor([0.0183])
# 수식을 w로 미분한 값 : tensor([-0.0080])
# 업데이트 된 W : tensor([-0.0080]), b : tensor([0.0183])
# 수식을 w로 미분한 값 : tensor([-0.0080])
# 업데이트 된 W : tensor([-0.0080]), b : tensor([0.0182])
# 수식을 w로 미분한 값 : tensor([-0.0080])
# 업데이트 된 W : tensor([-0.0080]), b : tensor([0.0182])
# 수식을 w로 미분한 값 : tensor([-0.0080])
# 업데이트 된 W : tensor([-0.0080]), b : tensor([0.0181])
# 수식을 w로 미분한 값 : tensor([-0.0080])
# 업데이트 된 W : tensor([-0.0080]), b : tensor([0.0181])
# 수식을 w로 미분한 값 : tensor([-0.0079])
# 업데이트 된 W : tensor([-0.0079]), b : tensor([0.0181])
# 수식을 w로 미분한 값 : tensor([-0.0079])
# 업데이트 된 W : tensor([-0.0079]), b : tensor([0.0180])
# 수식을 w로 미분한 값 : tensor([-0.0079])
# 업데이트 된 W : tensor([-0.0079]), b : tensor([0.0180])
# 수식을 w로 미분한 값 : tensor([-0.0079])
# 업데이트 된 W : tensor([-0.0079]), b : tensor([0.0179])
# 수식을 w로 미분한 값 : tensor([-0.0079])
# 업데이트 된 W : tensor([-0.0079]), b : tensor([0.0179])
# 수식을 w로 미분한 값 : tensor([-0.0078])
# 업데이트 된 W : tensor([-0.0078]), b : tensor([0.0178])
# 수식을 w로 미분한 값 : tensor([-0.0078])
# 업데이트 된 W : tensor([-0.0078]), b : tensor([0.0178])
# 수식을 w로 미분한 값 : tensor([-0.0078])
# 업데이트 된 W : tensor([-0.0078]), b : tensor([0.0178])
# 수식을 w로 미분한 값 : tensor([-0.0078])
# 업데이트 된 W : tensor([-0.0078]), b : tensor([0.0177])
# 수식을 w로 미분한 값 : tensor([-0.0078])
# 업데이트 된 W : tensor([-0.0078]), b : tensor([0.0177])
# 수식을 w로 미분한 값 : tensor([-0.0078])
# 업데이트 된 W : tensor([-0.0078]), b : tensor([0.0176])
# 수식을 w로 미분한 값 : tensor([-0.0077])
# 업데이트 된 W : tensor([-0.0077]), b : tensor([0.0176])
# 수식을 w로 미분한 값 : tensor([-0.0077])
# 업데이트 된 W : tensor([-0.0077]), b : tensor([0.0175])
# 수식을 w로 미분한 값 : tensor([-0.0077])
# 업데이트 된 W : tensor([-0.0077]), b : tensor([0.0175])
# 수식을 w로 미분한 값 : tensor([-0.0077])
# 업데이트 된 W : tensor([-0.0077]), b : tensor([0.0175])
# 수식을 w로 미분한 값 : tensor([-0.0077])
# 업데이트 된 W : tensor([-0.0077]), b : tensor([0.0174])
# 수식을 w로 미분한 값 : tensor([-0.0076])
# 업데이트 된 W : tensor([-0.0076]), b : tensor([0.0174])
# 수식을 w로 미분한 값 : tensor([-0.0076])
# 업데이트 된 W : tensor([-0.0076]), b : tensor([0.0173])
# 수식을 w로 미분한 값 : tensor([-0.0076])
# 업데이트 된 W : tensor([-0.0076]), b : tensor([0.0173])
# 수식을 w로 미분한 값 : tensor([-0.0076])
# 업데이트 된 W : tensor([-0.0076]), b : tensor([0.0172])
# 수식을 w로 미분한 값 : tensor([-0.0076])
# 업데이트 된 W : tensor([-0.0076]), b : tensor([0.0172])
# 수식을 w로 미분한 값 : tensor([-0.0076])
# 업데이트 된 W : tensor([-0.0076]), b : tensor([0.0172])
# 수식을 w로 미분한 값 : tensor([-0.0075])
# 업데이트 된 W : tensor([-0.0075]), b : tensor([0.0171])
# 수식을 w로 미분한 값 : tensor([-0.0075])
# 업데이트 된 W : tensor([-0.0075]), b : tensor([0.0171])
# 수식을 w로 미분한 값 : tensor([-0.0075])
# 업데이트 된 W : tensor([-0.0075]), b : tensor([0.0170])
# 수식을 w로 미분한 값 : tensor([-0.0075])
# 업데이트 된 W : tensor([-0.0075]), b : tensor([0.0170])
# 수식을 w로 미분한 값 : tensor([-0.0075])
# 업데이트 된 W : tensor([-0.0075]), b : tensor([0.0170])
# 수식을 w로 미분한 값 : tensor([-0.0074])
# 업데이트 된 W : tensor([-0.0074]), b : tensor([0.0169])
# 수식을 w로 미분한 값 : tensor([-0.0074])
# 업데이트 된 W : tensor([-0.0074]), b : tensor([0.0169])
# 수식을 w로 미분한 값 : tensor([-0.0074])
# 업데이트 된 W : tensor([-0.0074]), b : tensor([0.0168])
# 수식을 w로 미분한 값 : tensor([-0.0074])
# 업데이트 된 W : tensor([-0.0074]), b : tensor([0.0168])
# 수식을 w로 미분한 값 : tensor([-0.0074])
# 업데이트 된 W : tensor([-0.0074]), b : tensor([0.0168])
# 수식을 w로 미분한 값 : tensor([-0.0074])
# 업데이트 된 W : tensor([-0.0074]), b : tensor([0.0167])
# 수식을 w로 미분한 값 : tensor([-0.0073])
# 업데이트 된 W : tensor([-0.0073]), b : tensor([0.0167])
# 수식을 w로 미분한 값 : tensor([-0.0073])
# 업데이트 된 W : tensor([-0.0073]), b : tensor([0.0166])
# 수식을 w로 미분한 값 : tensor([-0.0073])
# 업데이트 된 W : tensor([-0.0073]), b : tensor([0.0166])
# 수식을 w로 미분한 값 : tensor([-0.0073])
# 업데이트 된 W : tensor([-0.0073]), b : tensor([0.0166])
# 수식을 w로 미분한 값 : tensor([-0.0073])
# 업데이트 된 W : tensor([-0.0073]), b : tensor([0.0165])
# 수식을 w로 미분한 값 : tensor([-0.0072])
# 업데이트 된 W : tensor([-0.0072]), b : tensor([0.0165])
# 수식을 w로 미분한 값 : tensor([-0.0072])
# 업데이트 된 W : tensor([-0.0072]), b : tensor([0.0164])
# 수식을 w로 미분한 값 : tensor([-0.0072])
# 업데이트 된 W : tensor([-0.0072]), b : tensor([0.0164])
# 수식을 w로 미분한 값 : tensor([-0.0072])
# 업데이트 된 W : tensor([-0.0072]), b : tensor([0.0164])
# 수식을 w로 미분한 값 : tensor([-0.0072])
# 업데이트 된 W : tensor([-0.0072]), b : tensor([0.0163])
# 수식을 w로 미분한 값 : tensor([-0.0072])
# 업데이트 된 W : tensor([-0.0072]), b : tensor([0.0163])
# 수식을 w로 미분한 값 : tensor([-0.0071])
# 업데이트 된 W : tensor([-0.0071]), b : tensor([0.0162])
# 수식을 w로 미분한 값 : tensor([-0.0071])
# 업데이트 된 W : tensor([-0.0071]), b : tensor([0.0162])
# 수식을 w로 미분한 값 : tensor([-0.0071])
# 업데이트 된 W : tensor([-0.0071]), b : tensor([0.0162])
# 수식을 w로 미분한 값 : tensor([-0.0071])
# 업데이트 된 W : tensor([-0.0071]), b : tensor([0.0161])
# 수식을 w로 미분한 값 : tensor([-0.0071])
# 업데이트 된 W : tensor([-0.0071]), b : tensor([0.0161])
# 수식을 w로 미분한 값 : tensor([-0.0071])
# 업데이트 된 W : tensor([-0.0071]), b : tensor([0.0160])
# 수식을 w로 미분한 값 : tensor([-0.0070])
# 업데이트 된 W : tensor([-0.0070]), b : tensor([0.0160])
# 수식을 w로 미분한 값 : tensor([-0.0070])
# 업데이트 된 W : tensor([-0.0070]), b : tensor([0.0160])
# 수식을 w로 미분한 값 : tensor([-0.0070])
# 업데이트 된 W : tensor([-0.0070]), b : tensor([0.0159])
# 수식을 w로 미분한 값 : tensor([-0.0070])
# 업데이트 된 W : tensor([-0.0070]), b : tensor([0.0159])
# 수식을 w로 미분한 값 : tensor([-0.0070])
# 업데이트 된 W : tensor([-0.0070]), b : tensor([0.0159])
# 수식을 w로 미분한 값 : tensor([-0.0070])
# 업데이트 된 W : tensor([-0.0070]), b : tensor([0.0158])
# 수식을 w로 미분한 값 : tensor([-0.0069])
# 업데이트 된 W : tensor([-0.0069]), b : tensor([0.0158])
# 수식을 w로 미분한 값 : tensor([-0.0069])
# 업데이트 된 W : tensor([-0.0069]), b : tensor([0.0157])
# 수식을 w로 미분한 값 : tensor([-0.0069])
# 업데이트 된 W : tensor([-0.0069]), b : tensor([0.0157])
# 수식을 w로 미분한 값 : tensor([-0.0069])
# 업데이트 된 W : tensor([-0.0069]), b : tensor([0.0157])
# Epoch  200/1999 W: 1.971, b: 0.065 Cost: 0.000609
# 수식을 w로 미분한 값 : tensor([-0.0069])
# 업데이트 된 W : tensor([-0.0069]), b : tensor([0.0156])
# 수식을 w로 미분한 값 : tensor([-0.0069])
# 업데이트 된 W : tensor([-0.0069]), b : tensor([0.0156])
# 수식을 w로 미분한 값 : tensor([-0.0068])
# 업데이트 된 W : tensor([-0.0068]), b : tensor([0.0155])
# 수식을 w로 미분한 값 : tensor([-0.0068])
# 업데이트 된 W : tensor([-0.0068]), b : tensor([0.0155])
# 수식을 w로 미분한 값 : tensor([-0.0068])
# 업데이트 된 W : tensor([-0.0068]), b : tensor([0.0155])
# 수식을 w로 미분한 값 : tensor([-0.0068])
# 업데이트 된 W : tensor([-0.0068]), b : tensor([0.0154])
# 수식을 w로 미분한 값 : tensor([-0.0068])
# 업데이트 된 W : tensor([-0.0068]), b : tensor([0.0154])
# 수식을 w로 미분한 값 : tensor([-0.0068])
# 업데이트 된 W : tensor([-0.0068]), b : tensor([0.0154])
# 수식을 w로 미분한 값 : tensor([-0.0067])
# 업데이트 된 W : tensor([-0.0067]), b : tensor([0.0153])
# 수식을 w로 미분한 값 : tensor([-0.0067])
# 업데이트 된 W : tensor([-0.0067]), b : tensor([0.0153])
# 수식을 w로 미분한 값 : tensor([-0.0067])
# 업데이트 된 W : tensor([-0.0067]), b : tensor([0.0153])
# 수식을 w로 미분한 값 : tensor([-0.0067])
# 업데이트 된 W : tensor([-0.0067]), b : tensor([0.0152])
# 수식을 w로 미분한 값 : tensor([-0.0067])
# 업데이트 된 W : tensor([-0.0067]), b : tensor([0.0152])
# 수식을 w로 미분한 값 : tensor([-0.0067])
# 업데이트 된 W : tensor([-0.0067]), b : tensor([0.0151])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0151])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0151])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0150])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0150])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0150])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0149])
# 수식을 w로 미분한 값 : tensor([-0.0066])
# 업데이트 된 W : tensor([-0.0066]), b : tensor([0.0149])
# 수식을 w로 미분한 값 : tensor([-0.0065])
# 업데이트 된 W : tensor([-0.0065]), b : tensor([0.0149])
# 수식을 w로 미분한 값 : tensor([-0.0065])
# 업데이트 된 W : tensor([-0.0065]), b : tensor([0.0148])
# 수식을 w로 미분한 값 : tensor([-0.0065])
# 업데이트 된 W : tensor([-0.0065]), b : tensor([0.0148])
# 수식을 w로 미분한 값 : tensor([-0.0065])
# 업데이트 된 W : tensor([-0.0065]), b : tensor([0.0147])
# 수식을 w로 미분한 값 : tensor([-0.0065])
# 업데이트 된 W : tensor([-0.0065]), b : tensor([0.0147])
# 수식을 w로 미분한 값 : tensor([-0.0065])
# 업데이트 된 W : tensor([-0.0065]), b : tensor([0.0147])
# 수식을 w로 미분한 값 : tensor([-0.0064])
# 업데이트 된 W : tensor([-0.0064]), b : tensor([0.0146])
# 수식을 w로 미분한 값 : tensor([-0.0064])
# 업데이트 된 W : tensor([-0.0064]), b : tensor([0.0146])
# 수식을 w로 미분한 값 : tensor([-0.0064])
# 업데이트 된 W : tensor([-0.0064]), b : tensor([0.0146])
# 수식을 w로 미분한 값 : tensor([-0.0064])
# 업데이트 된 W : tensor([-0.0064]), b : tensor([0.0145])
# 수식을 w로 미분한 값 : tensor([-0.0064])
# 업데이트 된 W : tensor([-0.0064]), b : tensor([0.0145])
# 수식을 w로 미분한 값 : tensor([-0.0064])
# 업데이트 된 W : tensor([-0.0064]), b : tensor([0.0145])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0144])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0144])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0144])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0143])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0143])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0143])
# 수식을 w로 미분한 값 : tensor([-0.0063])
# 업데이트 된 W : tensor([-0.0063]), b : tensor([0.0142])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0142])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0142])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0141])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0141])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0141])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0140])
# 수식을 w로 미분한 값 : tensor([-0.0062])
# 업데이트 된 W : tensor([-0.0062]), b : tensor([0.0140])
# 수식을 w로 미분한 값 : tensor([-0.0061])
# 업데이트 된 W : tensor([-0.0061]), b : tensor([0.0140])
# 수식을 w로 미분한 값 : tensor([-0.0061])
# 업데이트 된 W : tensor([-0.0061]), b : tensor([0.0139])
# 수식을 w로 미분한 값 : tensor([-0.0061])
# 업데이트 된 W : tensor([-0.0061]), b : tensor([0.0139])
# 수식을 w로 미분한 값 : tensor([-0.0061])
# 업데이트 된 W : tensor([-0.0061]), b : tensor([0.0139])
# 수식을 w로 미분한 값 : tensor([-0.0061])
# 업데이트 된 W : tensor([-0.0061]), b : tensor([0.0138])
# 수식을 w로 미분한 값 : tensor([-0.0061])
# 업데이트 된 W : tensor([-0.0061]), b : tensor([0.0138])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0138])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0137])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0137])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0137])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0136])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0136])
# 수식을 w로 미분한 값 : tensor([-0.0060])
# 업데이트 된 W : tensor([-0.0060]), b : tensor([0.0136])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0135])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0135])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0135])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0134])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0134])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0134])
# 수식을 w로 미분한 값 : tensor([-0.0059])
# 업데이트 된 W : tensor([-0.0059]), b : tensor([0.0133])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0133])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0133])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0132])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0132])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0132])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0131])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0131])
# 수식을 w로 미분한 값 : tensor([-0.0058])
# 업데이트 된 W : tensor([-0.0058]), b : tensor([0.0131])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0130])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0130])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0130])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0129])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0129])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0129])
# 수식을 w로 미분한 값 : tensor([-0.0057])
# 업데이트 된 W : tensor([-0.0057]), b : tensor([0.0129])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0128])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0128])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0128])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0127])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0127])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0127])
# 수식을 w로 미분한 값 : tensor([-0.0056])
# 업데이트 된 W : tensor([-0.0056]), b : tensor([0.0126])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0126])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0126])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0126])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0125])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0125])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0125])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0124])
# 수식을 w로 미분한 값 : tensor([-0.0055])
# 업데이트 된 W : tensor([-0.0055]), b : tensor([0.0124])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0124])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0123])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0123])
# Epoch  300/1999 W: 1.978, b: 0.051 Cost: 0.000376
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0123])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0123])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0122])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0122])
# 수식을 w로 미분한 값 : tensor([-0.0054])
# 업데이트 된 W : tensor([-0.0054]), b : tensor([0.0122])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0121])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0121])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0121])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0120])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0120])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0120])
# 수식을 w로 미분한 값 : tensor([-0.0053])
# 업데이트 된 W : tensor([-0.0053]), b : tensor([0.0120])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0119])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0119])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0119])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0118])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0118])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0118])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0118])
# 수식을 w로 미분한 값 : tensor([-0.0052])
# 업데이트 된 W : tensor([-0.0052]), b : tensor([0.0117])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0117])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0117])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0116])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0116])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0116])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0116])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0115])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0115])
# 수식을 w로 미분한 값 : tensor([-0.0051])
# 업데이트 된 W : tensor([-0.0051]), b : tensor([0.0115])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0115])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0114])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0114])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0114])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0113])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0113])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0113])
# 수식을 w로 미분한 값 : tensor([-0.0050])
# 업데이트 된 W : tensor([-0.0050]), b : tensor([0.0113])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0112])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0112])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0112])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0112])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0111])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0111])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0111])
# 수식을 w로 미분한 값 : tensor([-0.0049])
# 업데이트 된 W : tensor([-0.0049]), b : tensor([0.0110])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0110])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0110])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0110])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0109])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0109])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0109])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0109])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0108])
# 수식을 w로 미분한 값 : tensor([-0.0048])
# 업데이트 된 W : tensor([-0.0048]), b : tensor([0.0108])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0108])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0108])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0107])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0107])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0107])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0107])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0106])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0106])
# 수식을 w로 미분한 값 : tensor([-0.0047])
# 업데이트 된 W : tensor([-0.0047]), b : tensor([0.0106])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0106])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0105])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0105])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0105])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0105])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0104])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0104])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0104])
# 수식을 w로 미분한 값 : tensor([-0.0046])
# 업데이트 된 W : tensor([-0.0046]), b : tensor([0.0104])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0103])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0103])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0103])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0103])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0102])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0102])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0102])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0102])
# 수식을 w로 미분한 값 : tensor([-0.0045])
# 업데이트 된 W : tensor([-0.0045]), b : tensor([0.0101])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0101])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0101])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0101])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0100])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0100])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0100])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0100])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0099])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0099])
# 수식을 w로 미분한 값 : tensor([-0.0044])
# 업데이트 된 W : tensor([-0.0044]), b : tensor([0.0099])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0099])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0098])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0098])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0098])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0098])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0097])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0097])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0097])
# 수식을 w로 미분한 값 : tensor([-0.0043])
# 업데이트 된 W : tensor([-0.0043]), b : tensor([0.0097])
# Epoch  400/1999 W: 1.982, b: 0.040 Cost: 0.000233
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0097])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0096])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0096])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0096])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0096])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0095])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0095])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0095])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0095])
# 수식을 w로 미분한 값 : tensor([-0.0042])
# 업데이트 된 W : tensor([-0.0042]), b : tensor([0.0094])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0094])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0094])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0094])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0094])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0093])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0093])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0093])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0093])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0092])
# 수식을 w로 미분한 값 : tensor([-0.0041])
# 업데이트 된 W : tensor([-0.0041]), b : tensor([0.0092])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0092])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0092])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0092])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0091])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0091])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0091])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0091])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0090])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0090])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0090])
# 수식을 w로 미분한 값 : tensor([-0.0040])
# 업데이트 된 W : tensor([-0.0040]), b : tensor([0.0090])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0090])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0089])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0089])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0089])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0089])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0089])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0088])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0088])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0088])
# 수식을 w로 미분한 값 : tensor([-0.0039])
# 업데이트 된 W : tensor([-0.0039]), b : tensor([0.0088])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0087])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0087])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0087])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0087])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0087])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0086])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0086])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0086])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0086])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0086])
# 수식을 w로 미분한 값 : tensor([-0.0038])
# 업데이트 된 W : tensor([-0.0038]), b : tensor([0.0085])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0085])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0085])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0085])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0085])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0084])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0084])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0084])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0084])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0084])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0083])
# 수식을 w로 미분한 값 : tensor([-0.0037])
# 업데이트 된 W : tensor([-0.0037]), b : tensor([0.0083])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0083])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0083])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0083])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0082])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0082])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0082])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0082])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0082])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0081])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0081])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0081])
# 수식을 w로 미분한 값 : tensor([-0.0036])
# 업데이트 된 W : tensor([-0.0036]), b : tensor([0.0081])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0081])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0080])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0080])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0080])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0080])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0080])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0079])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0079])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0079])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0079])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0079])
# 수식을 w로 미분한 값 : tensor([-0.0035])
# 업데이트 된 W : tensor([-0.0035]), b : tensor([0.0078])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0078])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0078])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0078])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0078])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0078])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0077])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0077])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0077])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0077])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0077])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0076])
# 수식을 w로 미분한 값 : tensor([-0.0034])
# 업데이트 된 W : tensor([-0.0034]), b : tensor([0.0076])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0076])
# Epoch  500/1999 W: 1.986, b: 0.032 Cost: 0.000144
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0076])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0076])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0076])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0075])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0075])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0075])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0075])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0075])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0074])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0074])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0074])
# 수식을 w로 미분한 값 : tensor([-0.0033])
# 업데이트 된 W : tensor([-0.0033]), b : tensor([0.0074])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0074])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0074])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0073])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0073])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0073])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0073])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0073])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0072])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0072])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0072])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0072])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0072])
# 수식을 w로 미분한 값 : tensor([-0.0032])
# 업데이트 된 W : tensor([-0.0032]), b : tensor([0.0072])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0071])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0071])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0071])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0071])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0071])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0071])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0070])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0070])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0070])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0070])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0070])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0070])
# 수식을 w로 미분한 값 : tensor([-0.0031])
# 업데이트 된 W : tensor([-0.0031]), b : tensor([0.0069])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0069])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0069])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0069])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0069])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0069])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0068])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0068])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0068])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0068])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0068])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0068])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0067])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0067])
# 수식을 w로 미분한 값 : tensor([-0.0030])
# 업데이트 된 W : tensor([-0.0030]), b : tensor([0.0067])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0067])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0067])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0067])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0066])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0065])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0065])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0065])
# 수식을 w로 미분한 값 : tensor([-0.0029])
# 업데이트 된 W : tensor([-0.0029]), b : tensor([0.0065])
# 수식을 w로 미분한 값 : tensor([-0.0028])
# ...
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# Epoch 1900/1999 W: 2.000, b: 0.001 Cost: 0.000000
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0003])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9341e-05])
# 업데이트 된 W : tensor([-9.9341e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9818e-05])
# 업데이트 된 W : tensor([-9.9818e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9500e-05])
# 업데이트 된 W : tensor([-9.9500e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9977e-05])
# 업데이트 된 W : tensor([-9.9977e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9500e-05])
# 업데이트 된 W : tensor([-9.9500e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9977e-05])
# 업데이트 된 W : tensor([-9.9977e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9977e-05])
# 업데이트 된 W : tensor([-9.9977e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-0.0001])
# 업데이트 된 W : tensor([-0.0001]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9977e-05])
# 업데이트 된 W : tensor([-9.9977e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9500e-05])
# 업데이트 된 W : tensor([-9.9500e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9341e-05])
# 업데이트 된 W : tensor([-9.9341e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.8864e-05])
# 업데이트 된 W : tensor([-9.8864e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9500e-05])
# 업데이트 된 W : tensor([-9.9500e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.9341e-05])
# 업데이트 된 W : tensor([-9.9341e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.8864e-05])
# 업데이트 된 W : tensor([-9.8864e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.8705e-05])
# 업데이트 된 W : tensor([-9.8705e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.8228e-05])
# 업데이트 된 W : tensor([-9.8228e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.8069e-05])
# 업데이트 된 W : tensor([-9.8069e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.7593e-05])
# 업데이트 된 W : tensor([-9.7593e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.7434e-05])
# 업데이트 된 W : tensor([-9.7434e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.6957e-05])
# 업데이트 된 W : tensor([-9.6957e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.6798e-05])
# 업데이트 된 W : tensor([-9.6798e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.6321e-05])
# 업데이트 된 W : tensor([-9.6321e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.6162e-05])
# 업데이트 된 W : tensor([-9.6162e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.4891e-05])
# 업데이트 된 W : tensor([-9.4891e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.4414e-05])
# 업데이트 된 W : tensor([-9.4414e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.4255e-05])
# 업데이트 된 W : tensor([-9.4255e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.3778e-05])
# 업데이트 된 W : tensor([-9.3778e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.3619e-05])
# 업데이트 된 W : tensor([-9.3619e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.3142e-05])
# 업데이트 된 W : tensor([-9.3142e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.1871e-05])
# 업데이트 된 W : tensor([-9.1871e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.1712e-05])
# 업데이트 된 W : tensor([-9.1712e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.1235e-05])
# 업데이트 된 W : tensor([-9.1235e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-9.1076e-05])
# 업데이트 된 W : tensor([-9.1076e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-8.9804e-05])
# 업데이트 된 W : tensor([-8.9804e-05]), b : tensor([0.0002])
# 수식을 w로 미분한 값 : tensor([-8.9327e-05])
# 업데이트 된 W : tensor([-8.9327e-05]), b : tensor([0.0002])

# %%
## 학습 완료 후의 W, b  텐서 값 확인
W.item(), b.item()
# Out:
# (1.9996228218078613, 0.0008575354586355388)

# %%
## x값 넣고 y값 확인
pre_y = W*3+b
pre_y.item()
# Out:
# 5.999725818634033

# %%
num=12
avg=3.45567

f'num = {num}, {num:*^10}, avg = {avg} {avg:10.3f}'
# Out:
# 'num = 12, ****12****, avg = 3.45567      3.456'

# %%
## optimizer.zero_grad()가 필요한 이유
## 미분을 통해 얻은 기울기를 이전에 계산된 기울기 값에 누적시키는 특징

w = torch.tensor(2.0, requires_grad=True)

nb_epochs = 20
for epoch in range(nb_epochs + 1):

  z = 2*w

  z.backward()
  print('수식을 w로 미분한 값 : {}'.format(w.grad))
# Out:
# 수식을 w로 미분한 값 : 2.0
# 수식을 w로 미분한 값 : 4.0
# 수식을 w로 미분한 값 : 6.0
# 수식을 w로 미분한 값 : 8.0
# 수식을 w로 미분한 값 : 10.0
# 수식을 w로 미분한 값 : 12.0
# 수식을 w로 미분한 값 : 14.0
# 수식을 w로 미분한 값 : 16.0
# 수식을 w로 미분한 값 : 18.0
# 수식을 w로 미분한 값 : 20.0
# 수식을 w로 미분한 값 : 22.0
# 수식을 w로 미분한 값 : 24.0
# 수식을 w로 미분한 값 : 26.0
# 수식을 w로 미분한 값 : 28.0
# 수식을 w로 미분한 값 : 30.0
# 수식을 w로 미분한 값 : 32.0
# 수식을 w로 미분한 값 : 34.0
# 수식을 w로 미분한 값 : 36.0
# 수식을 w로 미분한 값 : 38.0
# 수식을 w로 미분한 값 : 40.0
# 수식을 w로 미분한 값 : 42.0
